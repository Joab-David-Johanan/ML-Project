# %%
import pandas as pd

# %%
df = pd.read_csv(
    r"C:\Users\joabd\Desktop\Projects\ML Project\data\br-anlagen-uebersicht-stand-12-2024-mit-koordinaten.csv"
)

# %%
df.head()
# Out:
#          name_anlage                               adresse      latitude  \
# 0             Allach        Oertelplatz (2), 80999 München  48°11'24.4"N
# 1  Amalienburgstraße   Menzinger/Schragenhofstr., 80638 Mü  48°09'56.7"N
# 2             Aubing           Colmdorfstr. (32), 81249 Mü  48°09'21.8"N
# 3       Berg am Laim  Truderinger Str. (47), 81673 München  48°08'01.4"N
# 4           Daglfing   Ludwig-Brück-Str. 3a, 81929 München  48°08'54.0"N
#
#       longitude  abstellplaetze bei_p+r_anlage bauform oepnv-anbindung
# 0  11°28'03.8"E             374              x      DF          S-Bahn
# 1  11°29'35.9"E              64            NaN      DF            Tram
# 2  11°24'49.6"E              56              x      DF          S-Bahn
# 3  11°38'00.2"E             154            NaN      DF          S-Bahn
# 4  11°38'59.2"E             122              x      EF          S-Bahn

# %%
df["bei_p+r_anlage"].unique()
# Out:
# <StringArray>
# ['x', nan]
# Length: 2, dtype: str

# %%
df["abstellplaetze"].unique()
# Out:
# array([374,  64,  56, 154, 122,  80,  96,  63,  40, 226,  86, 280,  48,
#        313, 124,  77,  50, 360, 755, 120, 392, 522,  62, 112,  34, 100,
#         10, 269, 186])
